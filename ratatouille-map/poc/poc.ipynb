# %%
import html
import re
import requests
import os
from dotenv import load_dotenv
import requests

# %% [markdown]
# fonte: https://gist.github.com/ByteSizedMarius/8c9df821ebb69b07f2d82de01e68387d <br>
# resposta stack overflow: https://stackoverflow.com/questions/50964713/obtain_list-of-my-places-from-google-maps/74957479#749574798

# %%
x: requests.Response = requests.get("https://google.com/maps/@/data=!3m1!4b1!4m3!11m2!2surLpP2IDzhnAsYrsgACRFjdCIiYM4A!3e3?entry=tts&g_ep=EgoyMDI1MDEyOC4wKgBIAVAD?ucbcb=1")

print(x.text)

txt = x.text.split(r")]}'\n")[2].split("]]\"],")[0] + "]]"
txt = html.unescape(txt)
# Out:
# <!DOCTYPE html><html itemscope="" itemtype="http://schema.org/Place" lang="en"> <head>  <link href="/maps/_/js/k=maps.m.en.neCMNYJF6Us.es5.O/m=sc2,per,mo,lp,ti,ds,stx,dwi,enr,b/am=4AAkB0gB/rt=j/d=1/rs=ACT90oGYaokPV51bEtFyex2N8P09AeT9Pg?wli=m.u_4DDbD180s.loadSv.O%3A%3B" as="script" rel="preload" type="application/javascript" nonce="go1Cj4mdyzEI-fCQUqVy5A">  <link href="/maps/preview/opensearch.xml?hl=en" title="Google Maps" rel="search" type="application/opensearchdescription+xml"> <title>  Google Maps  </title> <meta content=" Find local businesses, view maps and get driving directions in Google Maps. " name="Description">  <meta content="Google Maps" itemprop="name"> <meta content="Google Maps" property="og:title">  <meta content="https://maps.google.com/maps/api/staticmap?center=25.5584269%2C-80.458177&amp;zoom=8&amp;size=900x900&amp;language=en&amp;sensor=false&amp;client=google-maps-frontend&amp;signature=CNT9BP5P5HJlMP3FsnCwtpR-sOU" itemprop="image"> <meta content="https://maps.
# ...

# %%
txt
# Out:
# '[[[\\"urLpP2IDzhnAsYrsgACRFjdCIiYM4A\\",1,null,1,1],4,[3,1,\\"https://www.google.com/maps/placelists/list/urLpP2IDzhnAsYrsgACRFjdCIiYM4A\\"],[\\"Julia\\",\\"https://lh3.googleusercontent.com/a-/ALV-UjU1UITrnli_l6wUAngVROY3XPB1MecXLrgVsGkv1kNsPlQ0tm7QQw\\",\\"108220336166430929847\\"],\\"Restaurantes Vini e Ju ❤️\\",\\"Restaurantes próximos\\",null,null,[[null,[null,null,\\"\\",null,\\"R. Salete, 186 - Santana, São Paulo - SP, 02016-000\\",[null,null,-23.5022543,-46.627137399999995],[\\"-7723965642008646539\\",\\"-1793960607312454481\\"],\\"/g/1tvymy0k\\"],\\"Casa Libanesa\\",\\"\\",null,null,null,[],[[1],[\\"-7723965642008646539\\",\\"-1793960607312454481\\"]],[1741093831,760678000],[1741093831,760678000],null,[\\"Marina Tolentino\\",\\"https://lh3.googleusercontent.com/a-/ALV-UjX7aIM9BST2h9f2JlwXkSko7wP7jagXUpIYyHg5yyZwhU_a8hmFbg\\",\\"118311256256611025380\\"]],[null,[null,null,\\"\\",null,\\"R. Ismael Neri, 485 - Água Fria, São Paulo - SP, 02335-001\\",[null,null,-23.4809534,-46.
# ...

# %%
# todas as coordenadas
results = re.findall(r'\[null,null,(_?[0_9]+\.[0_9]+),(-?[0-9]+\.[0-9]+)\]', txt)
results
# Out:
# []

# %%
# matches = re.findall(r'\\"],\\"([^\\"]+)\\",\\"', txt)
# nomes dos restaurantes
comprehensive_matches = re.findall(r'(?:\\"/g/[^\\"]++\\"]|]]),\\"(.*?)\\",\\"', txt)

comprehensive_matches
# Out:
# ['Yunagi Edomae-zushi',
#  'Pinati',
#  'Panetteria Italianinha',
#  'Vinícola Urbana',
#  'Santokki',
#  'Lumi creamy',
#  'Ebi Pocket',
#  'Coliseum - Panini Italiani',
#  'Vesu Pizzaria',
#  'Momonoki Brasil',
#  'Fabrique Pão e Café',
#  'FOQUI Sanduíches',
#  'Terraço libanês',
#  'Izakayá Kaburá',
#  'Kinki-Zushi',
#  'Ombra',
#  'Ton Hoi',
#  'Sōzai Japanese Deli',
#  'Iza Padaria Artesanal',
#  'Restaurante Koufu',
#  'Casa Tavares',
#  'Motique',
#  'Vieira Zushi',
#  'Kan Suke',
#  'Sushi Vaz',
#  'Tabuleiro do Acarajé',
#  'Shiro Japanese cocktail bar',
#  'BICOL Korean Cuisine',
#  'Casa Hario',
#  'Boca de Ouro',
#  'Restaurante Aizomê',
#  'Plou Vinhos',
#  'Kubo Zushi',
#  'Hwang To Gil',
#  'The Punch Bar',
#  'Calfé Comercio de cafés',
#  'Casa Somauma',
#  'Tempura Ten',
#  'LosDos Cantina',
#  'Sorveteria e Lanchonete Ypê',
#  'Tau Cozinha',
#  'Hay Cozinha Armênia',
#  'São Cristóvão Bar e Restaurante',
#  'Churrascaria Oriental Cho Sun Gal Bi Bom Retiro',
# ...

# %%
load_dotenv(r"C:\Users\julia\Desktop\ratatouille-map\.gitignore\.env")
API_KEY = os.getenv('API_KEY')

# %%
# API URL
url = 'https://places.googleapis.com/v1/places:searchText'

# Headers
headers = {
    'Content-Type': 'application/json',
    'X-Goog-Api-Key': API_KEY, 
    'X-Goog-FieldMask': 'places.id,places.displayName,places.formattedAddress'
}

# Data to be sent in the request body
data = {
    'textQuery': comprehensive_matches[0]
}

# Make the POST request
response = requests.post(url, headers=headers, json=data)

# Check the response status and content
if response.status_code == 200:
    print("Response:", response.json())
else:
    print(f"Error {response.status_code}: {response.text}")
# Out:
# Response: {'places': [{'id': 'ChIJDTihe2lXzpQRp5eDyuREVy4', 'formattedAddress': 'R. Taperoá, 195 - Cidade Monções, São Paulo - SP, 04571-060, Brazil', 'displayName': {'text': 'Yunagi Edomae-zushi', 'languageCode': 'pt'}}]}

# %%
response_data = response.json()
response_data
# Out:
# {'places': [{'id': 'ChIJDTihe2lXzpQRp5eDyuREVy4',
#    'formattedAddress': 'R. Taperoá, 195 - Cidade Monções, São Paulo - SP, 04571-060, Brazil',
#    'displayName': {'text': 'Yunagi Edomae-zushi', 'languageCode': 'pt'}}]}

# %%
id = response_data['places'][0].get('id',None)
id
# Out:
# 'ChIJDTihe2lXzpQRp5eDyuREVy4'

# %%
# API URL
url = f'https://places.googleapis.com/v1/places/{id}'

# Fields as a list
field_list = [
    "formattedAddress",
    "location",
    "googleMapsUri",
    "types",
    "primaryTypeDisplayName",
    "websiteUri",
    "regularOpeningHours",
    "businessStatus",
    "editorialSummary",
    "priceLevel",
    "rating",
    "servesVegetarianFood"
]

# Convert the list to a comma-separated string
fields = ",".join(field_list)

# Headers
headers = {
    'Content-Type': 'application/json',
    'X-Goog-Api-Key': API_KEY,
    'X-Goog-FieldMask': fields,
    'Accept-Language': 'pt-BR'
    }

# Make the POST request
response = requests.get(url, headers=headers)
print(response.text)

# Check the response status and content
if response.status_code == 200:
    print("Response:", response.json())
else:
    print(f"Error {response.status_code}: {response.text}")
# Out:
# {
#   "types": [
#     "japanese_restaurant",
#     "restaurant",
#     "food",
#     "point_of_interest",
#     "establishment"
#   ],
#   "formattedAddress": "R. Taperoá, 195 - Cidade Monções, São Paulo - SP, 04571-060, Brasil",
#   "location": {
#     "latitude": -23.602349600000004,
#     "longitude": -46.691389
#   },
#   "rating": 4.9,
#   "googleMapsUri": "https://maps.google.com/?cid=3339213398159366055",
#   "websiteUri": "https://www.instagram.com/yunagi_edomaezushi/",
#   "regularOpeningHours": {
#     "openNow": false,
#     "periods": [
#       {
#         "open": {
#           "day": 2,
#           "hour": 12,
#           "minute": 0
#         },
#         "close": {
#           "day": 2,
#           "hour": 14,
#           "minute": 30
#         }
#       },
#       {
#         "open": {
#           "day": 2,
#           "hour": 19,
#           "minute": 0
#         },
#         "close": {
#           "day": 2,
#           "hour": 22,
#           "minute": 0
# ...

# %%
id
# Out:
# 'ChIJDTihe2lXzpQRp5eDyuREVy4'

# %%
name = comprehensive_matches[0]

# %%
response = response.json()
response
# Out:
# {'types': ['japanese_restaurant',
#   'restaurant',
#   'food',
#   'point_of_interest',
#   'establishment'],
#  'formattedAddress': 'R. Taperoá, 195 - Cidade Monções, São Paulo - SP, 04571-060, Brasil',
#  'location': {'latitude': -23.602349600000004, 'longitude': -46.691389},
#  'rating': 4.9,
#  'googleMapsUri': 'https://maps.google.com/?cid=3339213398159366055',
#  'websiteUri': 'https://www.instagram.com/yunagi_edomaezushi/',
#  'regularOpeningHours': {'openNow': False,
#   'periods': [{'open': {'day': 2, 'hour': 12, 'minute': 0},
#     'close': {'day': 2, 'hour': 14, 'minute': 30}},
#    {'open': {'day': 2, 'hour': 19, 'minute': 0},
#     'close': {'day': 2, 'hour': 22, 'minute': 0}},
#    {'open': {'day': 3, 'hour': 12, 'minute': 0},
#     'close': {'day': 3, 'hour': 14, 'minute': 30}},
#    {'open': {'day': 3, 'hour': 19, 'minute': 0},
#     'close': {'day': 3, 'hour': 22, 'minute': 0}},
#    {'open': {'day': 4, 'hour': 12, 'minute': 0},
# ...

# %%
response['regularOpeningHours'].get('periods')
# Out:
# [{'open': {'day': 2, 'hour': 12, 'minute': 0},
#   'close': {'day': 2, 'hour': 14, 'minute': 30}},
#  {'open': {'day': 2, 'hour': 19, 'minute': 0},
#   'close': {'day': 2, 'hour': 22, 'minute': 0}},
#  {'open': {'day': 3, 'hour': 12, 'minute': 0},
#   'close': {'day': 3, 'hour': 14, 'minute': 30}},
#  {'open': {'day': 3, 'hour': 19, 'minute': 0},
#   'close': {'day': 3, 'hour': 22, 'minute': 0}},
#  {'open': {'day': 4, 'hour': 12, 'minute': 0},
#   'close': {'day': 4, 'hour': 14, 'minute': 30}},
#  {'open': {'day': 4, 'hour': 19, 'minute': 0},
#   'close': {'day': 4, 'hour': 22, 'minute': 0}},
#  {'open': {'day': 5, 'hour': 12, 'minute': 0},
#   'close': {'day': 5, 'hour': 14, 'minute': 30}},
#  {'open': {'day': 5, 'hour': 19, 'minute': 0},
#   'close': {'day': 5, 'hour': 22, 'minute': 0}},
#  {'open': {'day': 6, 'hour': 12, 'minute': 0},
#   'close': {'day': 6, 'hour': 14, 'minute': 30}},
#  {'open': {'day': 6, 'hour': 19, 'minute': 0},
# ...

# %%
def convert_opening_hours_to_dynamodb_format(openinghours_periods):
    result = []

    if not openinghours_periods:
        return result

    for period in openinghours_periods:
        # Opening hours 
        open_data = period.get("open", {})
        day_of_week = open_data.get("day", 0)
        open_hour = str(open_data.get("hour", 0)).zfill(2)
        open_minute = str(open_data.get("minute", 0)).zfill(2)
        opens_time = f"{open_hour}:{open_minute}"

        # Closing hours 
        close_data = period.get("close", {})
        close_hour = str(close_data.get("hour", 0)).zfill(2)
        close_minute = str(close_data.get("minute", 0)).zfill(2)
        closes_time = f"{close_hour}:{close_minute}"
        
        # Create DynamoDB format
        period_entry = {
                "day_of_the_week": str(day_of_week),
                "opens": opens_time,
                "closes": closes_time,
                "is_opened": True
        }
    
        result.append(period_entry)

    opened_days = set(period["open"].get('day') for period in openinghours_periods)
    
    # Closed days are not shown in the API response
    for day_of_week in range(7):
        if day_of_week not in opened_days:
            closed_day_entry = {
                    "day_of_the_week": str(day_of_week),
                    "is_opened": False
            }
            result.append(closed_day_entry)
    
    return result

# %%
response['regularOpeningHours'].get('periods')
# Out:
# [{'open': {'day': 2, 'hour': 12, 'minute': 0},
#   'close': {'day': 2, 'hour': 14, 'minute': 30}},
#  {'open': {'day': 2, 'hour': 19, 'minute': 0},
#   'close': {'day': 2, 'hour': 22, 'minute': 0}},
#  {'open': {'day': 3, 'hour': 12, 'minute': 0},
#   'close': {'day': 3, 'hour': 14, 'minute': 30}},
#  {'open': {'day': 3, 'hour': 19, 'minute': 0},
#   'close': {'day': 3, 'hour': 22, 'minute': 0}},
#  {'open': {'day': 4, 'hour': 12, 'minute': 0},
#   'close': {'day': 4, 'hour': 14, 'minute': 30}},
#  {'open': {'day': 4, 'hour': 19, 'minute': 0},
#   'close': {'day': 4, 'hour': 22, 'minute': 0}},
#  {'open': {'day': 5, 'hour': 12, 'minute': 0},
#   'close': {'day': 5, 'hour': 14, 'minute': 30}},
#  {'open': {'day': 5, 'hour': 19, 'minute': 0},
#   'close': {'day': 5, 'hour': 22, 'minute': 0}},
#  {'open': {'day': 6, 'hour': 12, 'minute': 0},
#   'close': {'day': 6, 'hour': 14, 'minute': 30}},
#  {'open': {'day': 6, 'hour': 19, 'minute': 0},
# ...

# %%
convert_opening_hours_to_dynamodb_format(response['regularOpeningHours'].get('periods'))
# Out:
# [{'day_of_the_week': '2',
#   'opens': '12:00',
#   'closes': '14:30',
#   'is_opened': True},
#  {'day_of_the_week': '2',
#   'opens': '19:00',
#   'closes': '22:00',
#   'is_opened': True},
#  {'day_of_the_week': '3',
#   'opens': '12:00',
#   'closes': '14:30',
#   'is_opened': True},
#  {'day_of_the_week': '3',
#   'opens': '19:00',
#   'closes': '22:00',
#   'is_opened': True},
#  {'day_of_the_week': '4',
#   'opens': '12:00',
#   'closes': '14:30',
#   'is_opened': True},
#  {'day_of_the_week': '4',
#   'opens': '19:00',
#   'closes': '22:00',
#   'is_opened': True},
#  {'day_of_the_week': '5',
#   'opens': '12:00',
#   'closes': '14:30',
#   'is_opened': True},
#  {'day_of_the_week': '5',
#   'opens': '19:00',
#   'closes': '22:00',
#   'is_opened': True},
#  {'day_of_the_week': '6',
#   'opens': '12:00',
#   'closes': '14:30',
#   'is_opened': True},
#  {'day_of_the_week': '6',
#   'opens': '19:00',
#   'closes': '22:00',
#   'is_opened': True},
# ...

# %%
if response.get('regularOpeningHours'):
    openinghours = convert_opening_hours_to_dynamodb_format(response['regularOpeningHours'].get('periods'))
    if response['regularOpeningHours'].get('weekdayDescriptions'):
        weekday_descriptions =
        openinghoursdescription =  [description.replace('\u2009', '') for description in  response['regularOpeningHours'].get('weekdayDescriptions')]

openinghoursdescription
# Out:
# ['segunda-feira: Fechado',
#  'terça-feira: 12:00–14:30, 19:00–22:00',
#  'quarta-feira: 12:00–14:30, 19:00–22:00',
#  'quinta-feira: 12:00–14:30, 19:00–22:00',
#  'sexta-feira: 12:00–14:30, 19:00–22:00',
#  'sábado: 12:00–14:30, 19:00–22:00',
#  'domingo: Fechado']

# %%
item_data = {
    'google_id': id,
    'google_name': name,
    'google_url': response.get('googleMapsUri', ''),
    'address': response.get('formattedAddress', ''),
    'latitude': str(response['location'].get('latitude', '')),
    'longitude': str(response['location'].get('longitude', ''))
}

# Fields that might be None - store as NULL if they are None
optional_fields = [
    ('restaurant_types', response.get('types') if 'types' in response else None),
    ('primary_restaurant_type', response.get('primaryTypeDisplayName', {}).get('text')),
    ('business_status', response.get('businessStatus')),
    ('website', response.get('websiteUri') if 'websiteUri' in response else None),
    ('opening_hours_description', openinghoursdescription if 'regularOpeningHours' in response else None),
    ('opening_hours', openinghours if 'regularOpeningHours' in response else None),
    ('editorial_summary', response.get('editorialSummary', {}).get('text') if 'editorialSummary' in response else None),
    ('ratings', str(response.get('rating')) if 'rating' in response else None),
    ('vegetarian_food', response.get('servesVegetarianFood')  if 'servesVegetarianFood' in response else None)
]

optional_flags = [('vegetarian_food', response.get('servesVegetarianFood'))]

for field_name, field_value in optional_fields:
    if field_value is not None:
        if field_name == 'opening_hours' or  field_name == 'restaurant_types' or  field_name == 'opening_hours_description':
            item_data[field_name] = field_value
        elif field_name == 'ratings':
            item_data[field_name] = field_value
        elif field_name == 'vegetarian_food':
            item_data[field_name] = field_value
        else:
            item_data[field_name] = field_value
    else:
        item_data[field_name] = None

# %%
item_data
# Out:
# {'google_id': 'ChIJDTihe2lXzpQRp5eDyuREVy4',
#  'google_name': 'Yunagi Edomae-zushi',
#  'google_url': 'https://maps.google.com/?cid=3339213398159366055',
#  'address': 'R. Taperoá, 195 - Cidade Monções, São Paulo - SP, 04571-060, Brasil',
#  'latitude': '-23.602349600000004',
#  'longitude': '-46.691389',
#  'restaurant_types': ['japanese_restaurant',
#   'restaurant',
#   'food',
#   'point_of_interest',
#   'establishment'],
#  'primary_restaurant_type': 'Restaurante japonês',
#  'business_status': 'OPERATIONAL',
#  'website': 'https://www.instagram.com/yunagi_edomaezushi/',
#  'opening_hours_description': ['segunda-feira: Fechado',
#   'terça-feira: 12:00–14:30, 19:00–22:00',
#   'quarta-feira: 12:00–14:30, 19:00–22:00',
#   'quinta-feira: 12:00–14:30, 19:00–22:00',
#   'sexta-feira: 12:00–14:30, 19:00–22:00',
#   'sábado: 12:00–14:30, 19:00–22:00',
#   'domingo: Fechado'],
#  'opening_hours': [{'day_of_the_week': '2',
#    'opens': '12:00',
#    'closes': '14:30',
# ...

# %%
# #dynamodb.put_item(TableName='fruitSalad', Item={'fruitName':{'S':'Banana'},'key2':{'N':'value2'}})
# import boto3

# session = boto3.Session(
#     aws_access_key_id=os.getenv('AWS_ACCESS_KEY'),
#     aws_secret_access_key=os.getenv('AWS_SECRET_KEY')
# )

# dynamodb = session.resource('dynamodb', region_name='us-east-1')

# table = dynamodb.Table('map_data')

# table.put_item(Item=item_data)
